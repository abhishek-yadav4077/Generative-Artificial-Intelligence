# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-3.0.6-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.5.3-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached tzdata-2026.4-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-3.0.6-cp313-cp313-win_amd64.whl (9.6 MB)
# Using cached numpy-2.5.3-cp313-cp313-win_amd64.whl (12.6 MB)
# Using cached tzdata-2026.4-py2.py3-none-any.whl (347 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Pandas Series is a column of data in a table like in excel or google sheets with labels called as indexes attached to each value.

# %%
pd.Series(data=[40,50,60], index=['Bread','Milk','Butter'])
# Out:
# Bread     40
# Milk      50
# Butter    60
# dtype: int64

# %%
pd.Series(data=[40,50,60], index=['Bread','Milk','Butter'], name='Price of grocery items')
# Out:
# Bread     40
# Milk      50
# Butter    60
# Name: Price of grocery items, dtype: int64

# %% [markdown]
# #### Series is a 1-d array that can hold any type of data like integers, floats, boolean, string (objects), mixed data types

# %% [markdown]
# ## Data type ---> integers --> data in a Series (column) --> Quantity of items in the stock
# ## Data type ---> Float ---> data in a Series (column) ---> Price or product ratings
# ## Data type ---> String --> data in a Series (column) ---> Product name
# ## Data type ---> boolean --> data in a Series (column) ---> Is item in stock ?
# ## Data type ---> Data/ Time --> data in a Series (column) ---> Expiry dates or sale dates
# ## Mixed type ---> Milk, 40, True

# %% [markdown]
# ## Creating a Series in Multiple ways :-
# #### 1. List
# #### 2. NumPy array
# #### 3. Dictionary
# #### 4. Custom index
# #### 5. Scalar value

# %%
## Series from list:-

country=['India','China','USA','Pakistan']

pd.Series(country)
# Out:
# 0       India
# 1       China
# 2         USA
# 3    Pakistan
# dtype: str

# %%
batsman_runs = [48,64,72,98,114,183]


pd.Series(batsman_runs)
# pd.Series(batsman_runs, dtype='int32')
# Out:
# 0     48
# 1     64
# 2     72
# 3     98
# 4    114
# 5    183
# dtype: int64

# %%
subject_names = ['Maths','Physics','Chemistry','Biology','English']

subject_marks = [48,92,64,35,98]

pd.Series(data=subject_marks, index=subject_names, name='Subject marks data', dtype='int32')
# Out:
# Maths        48
# Physics      92
# Chemistry    64
# Biology      35
# English      98
# Name: Subject marks data, dtype: int32

# %%
### Creating a Series using a NumPy array

values = np.arange(10,21)
pd.Series(values)
# Out:
# 0     10
# 1     11
# 2     12
# 3     13
# 4     14
# 5     15
# 6     16
# 7     17
# 8     18
# 9     19
# 10    20
# dtype: int64

# %%
## Dictionary to Series

## Dictionary is another data structure that stores the data in a key:value pair and 
## just because it stores the data in a key:value pair so we don't have to explicitly mention the index.

# %%
data_items = {'Marks':78, 'English':92, 'Physics':88, 'Chemistry':64}
pd.Series(data_items)
# Out:
# Marks        78
# English      92
# Physics      88
# Chemistry    64
# dtype: int64

# %%
## custom index to series

values = [1,2,3,4,5]
pd.Series(data=values, index=['a','b','c','d','e'])
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
## Scalar value inside a Series 

pd.Series(4,index=['a','b','c','d','e'])
# Out:
# a    4
# b    4
# c    4
# d    4
# e    4
# dtype: int64

# %% [markdown]
# ## read_csv() ---> 90% is being used --> this function reads the content from the csv file in pandas dataframe format so that we can perform the operations on the data or we can perform effective analysis.

# %%
Data = pd.read_csv('C:/Users/Tarkeshwar/Desktop/ABHISHEK/Technical skills/Tutedude/Gen AI/Generative-Artificial-Intelligence/Machine Learning/Prerequisites/Module 8_Pandas/Pandas/youtube_2025_dataset_202504061614.csv')

# %%
Data
# Out:
#                      Channel Name       Youtuber Name  Total Videos  \
# 0                 Smith-Ross Labs          Eric Patel            68
# 1                Sandoval PLC Hub  Cynthia Harrington           128
# 2     Jones, Moore and Ho Network       Amanda Walker           282
# 3            Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4              Wilson LLC Studios     Matthew Sherman           129
# ...                           ...                 ...           ...
# 4995        Flores-Daniel Studios       Jasmine Smith           106
# 4996     Spencer and Sons Studios      John Rasmussen           130
# 4997       Obrien-Roberts Studios          Lisa Burke           179
# 4998                 King Ltd Hub          Steve Diaz           182
# 4999            Henry Ltd Studios         Austin Tate            92
#
#                               Best Video  Avg Video Length (min)  \
# 0              VR Challenge: Review 2023                    24.8
# ...

# %%
# 2nd way to read
df = pd.read_csv('youtube_2025_dataset_202504061614.csv')

# %%
df
# Out:
#                      Channel Name       Youtuber Name  Total Videos  \
# 0                 Smith-Ross Labs          Eric Patel            68
# 1                Sandoval PLC Hub  Cynthia Harrington           128
# 2     Jones, Moore and Ho Network       Amanda Walker           282
# 3            Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4              Wilson LLC Studios     Matthew Sherman           129
# ...                           ...                 ...           ...
# 4995        Flores-Daniel Studios       Jasmine Smith           106
# 4996     Spencer and Sons Studios      John Rasmussen           130
# 4997       Obrien-Roberts Studios          Lisa Burke           179
# 4998                 King Ltd Hub          Steve Diaz           182
# 4999            Henry Ltd Studios         Austin Tate            92
#
#                               Best Video  Avg Video Length (min)  \
# 0              VR Challenge: Review 2023                    24.8
# ...

# %%
## DataFrame --> Combination of multiple Series (Series means a single column)

# %%
## converting data frame to Series --> use squeeze parameter --> it make sure that the data is in Series format

# %%
pd.read_csv('youtube_one_column.csv')
# Out:
#                      Channel Name
# 0                 Smith-Ross Labs
# 1                Sandoval PLC Hub
# 2     Jones, Moore and Ho Network
# 3            Mitchell-Hooper Labs
# 4              Wilson LLC Studios
# ...                           ...
# 4995        Flores-Daniel Studios
# 4996     Spencer and Sons Studios
# 4997       Obrien-Roberts Studios
# 4998                 King Ltd Hub
# 4999            Henry Ltd Studios
#
# [5000 rows x 1 columns]

# %%
type(pd.read_csv('youtube_one_column.csv'))
# Out:
# pandas.DataFrame

# %%
## to convert data frame into Series :-

df = pd.read_csv('youtube_one_column.csv').squeeze('columns')

# %%
df
# Out:
# 0                   Smith-Ross Labs
# 1                  Sandoval PLC Hub
# 2       Jones, Moore and Ho Network
# 3              Mitchell-Hooper Labs
# 4                Wilson LLC Studios
#                    ...
# 4995          Flores-Daniel Studios
# 4996       Spencer and Sons Studios
# 4997         Obrien-Roberts Studios
# 4998                   King Ltd Hub
# 4999              Henry Ltd Studios
# Name: Channel Name, Length: 5000, dtype: str

# %%
type(df)
# Out:
# pandas.Series

# %%
pd.read_csv('youtube_two_column.csv')
# Out:
#            Youtuber Name  Total Videos
# 0             Eric Patel            68
# 1     Cynthia Harrington           128
# 2          Amanda Walker           282
# 3      Jessica Nelson MD           302
# 4        Matthew Sherman           129
# ...                  ...           ...
# 4995       Jasmine Smith           106
# 4996      John Rasmussen           130
# 4997          Lisa Burke           179
# 4998          Steve Diaz           182
# 4999         Austin Tate            92
#
# [5000 rows x 2 columns]

# %%
## index_col

# %%
dataframe = pd.read_csv('youtube_two_column.csv', index_col='Youtuber Name').squeeze('columns')

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int64

# %%
df
# Out:
# 0                   Smith-Ross Labs
# 1                  Sandoval PLC Hub
# 2       Jones, Moore and Ho Network
# 3              Mitchell-Hooper Labs
# 4                Wilson LLC Studios
#                    ...
# 4995          Flores-Daniel Studios
# 4996       Spencer and Sons Studios
# 4997         Obrien-Roberts Studios
# 4998                   King Ltd Hub
# 4999              Henry Ltd Studios
# Name: Channel Name, Length: 5000, dtype: str

# %% [markdown]
# ### Attribute in Series
#
# ### 1) .values --> representing only the values of the given series
# ### 2) .index --> returns only the index values from the given column
# ### 3) .dtype --> it provides the idea about the data type of the values that you are storing
# ### 4) .size --> this attribute provides the idea about the total number of rows inside the dataset
# ### 5) .shape --> this attribute provides the idea about the row, column information
# ### 6) .ndim --> this attribute provides the idea about the dimention of the given dataset
# ### 7) .name --> this attribute provides the idea about the name of the series
# ### 8) .is_unique --> this provides us with the idea about whether if unique values are there or not inside the column

# %%
df.values
# Out:
# <StringArray>
# [                    'Smith-Ross Labs',                    'Sandoval PLC Hub',
#          'Jones, Moore and Ho Network',                'Mitchell-Hooper Labs',
#                   'Wilson LLC Studios',                   'Myers Ltd Network',
#                    'Huber Inc Network',              'Baxter-Collins Studios',
#                    'Morrow-Abbott Hub',               'Jackson Group Network',
#  ...
#                      'Cole-Sharp Labs', 'Sherman, Mcgee and Phillips Studios',
#                       'Baker-Hill Hub',    'Francis, Davis and Jones Network',
#      'Whitaker, Horn and Escobar Labs',               'Flores-Daniel Studios',
#             'Spencer and Sons Studios',              'Obrien-Roberts Studios',
#                         'King Ltd Hub',                   'Henry Ltd Studios']
# Length: 5000, dtype: str

# %%
dataframe.values
# Out:
# array([ 68, 128, 282, ..., 179, 182,  92], shape=(5000,))

# %%
dataframe.index
# Out:
# Index(['Eric Patel', 'Cynthia Harrington', 'Amanda Walker',
#        'Jessica Nelson MD', 'Matthew Sherman', 'Anna Berry', 'Richard Arnold',
#        'Stephanie Potter', 'Teresa Aguirre', 'Anne Adkins',
#        ...
#        'Erin Bradley', 'Brooke Perez', 'Nicholas Jordan', 'Howard Phelps',
#        'Sharon Graham', 'Jasmine Smith', 'John Rasmussen', 'Lisa Burke',
#        'Steve Diaz', 'Austin Tate'],
#       dtype='str', name='Youtuber Name', length=5000)

# %%
dataframe.dtype
# Out:
# dtype('int64')

# %%
df.dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
dataframe = dataframe.astype('int32')

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int32

# %%
dataframe.size
# Out:
# 5000

# %%
dataframe.shape
# Out:
# (5000,)

# %%
dataframe.ndim
# Out:
# 1

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int32

# %%
dataframe.name
# Out:
# 'Total Videos'

# %%
dataframe.is_unique
# Out:
# False

# %%
pd.Series([1,2,3,4,5]).is_unique
# Out:
# True

# %% [markdown]
# ## Series methods
#
# #### 1) head() ---> provides the top preview of data as the top 5 rows of the dataframe or Series. It is quite helpful with providing the preview of the dataset and if we want to preview top 10 rows then we can pass 10 as the argument or for top 7 rows we can pass 7 as an argument.
#
# #### 2) tail() ---> provides the bottom preview of data as the bottom 5 rows
#
# #### for e.g. --> dataset --> salary column --> top 5 rows --> salary --> 7 lpa ---> top 10 ---> top 15 ,,, tail() ---> bottom 5 rows ---> salary --> 4 lpa, 9 lpa
#
# #### 3) sample() --> provides any custom row from the dataset for us to preview it.
#
# #### 4) value_counts() --> it provides the idea about the count of the values (categorical values), if i am having a column where the categorical value count i want to calculate then i can go with value_counts()
#
# #### 5) sort_values() --> this method sorts the value in an ascending manner. It can be useful for us for the numerical columns. you can even sort the values in descending manner as well.
#
# #### 6) sort_index() --> this method sorts the index of the dataset.

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int32

# %%
dataframe.head()
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
# Name: Total Videos, dtype: int32

# %%
dataframe.head(9)
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
# Anna Berry             98
# Richard Arnold        494
# Stephanie Potter      133
# Teresa Aguirre        316
# Name: Total Videos, dtype: int32

# %%
dataframe.head(21)
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
# Anna Berry             98
# Richard Arnold        494
# Stephanie Potter      133
# Teresa Aguirre        316
# Anne Adkins           140
# David Clark            52
# Kathleen Weeks        149
# Melissa Kennedy        53
# Kimberly Brown        299
# Jennifer Martinez     383
# Elizabeth Wright       79
# Elijah Ruiz           373
# Thomas Roberts         59
# Julian Gutierrez      500
# Sheila Rivera         332
# Crystal Vargas        133
# Name: Total Videos, dtype: int32

# %%
dataframe.tail()
# Out:
# Youtuber Name
# Jasmine Smith     106
# John Rasmussen    130
# Lisa Burke        179
# Steve Diaz        182
# Austin Tate        92
# Name: Total Videos, dtype: int32

# %%
df.head()
# Out:
# 0                Smith-Ross Labs
# 1               Sandoval PLC Hub
# 2    Jones, Moore and Ho Network
# 3           Mitchell-Hooper Labs
# 4             Wilson LLC Studios
# Name: Channel Name, dtype: str

# %%
df.tail()
# Out:
# 4995       Flores-Daniel Studios
# 4996    Spencer and Sons Studios
# 4997      Obrien-Roberts Studios
# 4998                King Ltd Hub
# 4999           Henry Ltd Studios
# Name: Channel Name, dtype: str

# %%
df.tail(11)
# Out:
# 4989                   Knight and Sons Labs
# 4990                        Cole-Sharp Labs
# 4991    Sherman, Mcgee and Phillips Studios
# 4992                         Baker-Hill Hub
# 4993       Francis, Davis and Jones Network
# 4994        Whitaker, Horn and Escobar Labs
# 4995                  Flores-Daniel Studios
# 4996               Spencer and Sons Studios
# 4997                 Obrien-Roberts Studios
# 4998                           King Ltd Hub
# 4999                      Henry Ltd Studios
# Name: Channel Name, dtype: str

# %%
df.sample()
# Out:
# 1958    Walker and Sons Studios
# Name: Channel Name, dtype: str

# %%
df.sample(5)
# Out:
# 1354    Johnson-Scott Network
# 2242      Johnson PLC Studios
# 522       Huffman-Hodges Labs
# 1262      Pennington Ltd Labs
# 255          Lee and Sons Hub
# Name: Channel Name, dtype: str

# %%
youtube = pd.read_csv('youtube_2025_dataset_202504061614.csv')

# %%
youtube
# Out:
#                      Channel Name       Youtuber Name  Total Videos  \
# 0                 Smith-Ross Labs          Eric Patel            68
# 1                Sandoval PLC Hub  Cynthia Harrington           128
# 2     Jones, Moore and Ho Network       Amanda Walker           282
# 3            Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4              Wilson LLC Studios     Matthew Sherman           129
# ...                           ...                 ...           ...
# 4995        Flores-Daniel Studios       Jasmine Smith           106
# 4996     Spencer and Sons Studios      John Rasmussen           130
# 4997       Obrien-Roberts Studios          Lisa Burke           179
# 4998                 King Ltd Hub          Steve Diaz           182
# 4999            Henry Ltd Studios         Austin Tate            92
#
#                               Best Video  Avg Video Length (min)  \
# 0              VR Challenge: Review 2023                    24.8
# ...

# %%
avg = youtube['Avg Video Length (min)']

# %%
avg
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
type(avg)
# Out:
# pandas.Series

# %%
avg.value_counts()
# Out:
# Avg Video Length (min)
# 24.1    276
# 23.8    264
# 23.9    256
# 24.2    253
# 24.0    251
#        ...
# 19.9      1
# 27.3      1
# 28.0      1
# 21.0      1
# 20.7      1
# Name: count, Length: 78, dtype: int64

# %%
df
# Out:
# 0                   Smith-Ross Labs
# 1                  Sandoval PLC Hub
# 2       Jones, Moore and Ho Network
# 3              Mitchell-Hooper Labs
# 4                Wilson LLC Studios
#                    ...
# 4995          Flores-Daniel Studios
# 4996       Spencer and Sons Studios
# 4997         Obrien-Roberts Studios
# 4998                   King Ltd Hub
# 4999              Henry Ltd Studios
# Name: Channel Name, Length: 5000, dtype: str

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int32

# %%
avg.sort_values()
# Out:
# 500     19.1
# 451     19.3
# 1713    19.9
# 171     20.6
# 3704    20.7
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
## parameter --> ascending = False (sorting --? descending)

avg.sort_values(ascending=False)
# Out:
# 361     28.9
# 1467    28.4
# 364     28.3
# 925     28.1
# 2748    28.0
#         ...
# 3704    20.7
# 171     20.6
# 1713    19.9
# 451     19.3
# 500     19.1
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %% [markdown]
# ## Method chaining --> we will use multiple methods together to get the required value in a way the first method's output will be second method's input then second's method output will be third method's input

# %%
avg.sort_values(ascending=False).head(1)
# Out:
# 361    28.9
# Name: Avg Video Length (min), dtype: float64

# %%
avg.sort_values(ascending=False).head(1).values[0]
# Out:
# np.float64(28.9)

# %%
avg
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
### In order to make a change in your data permanent --> inplace parameter

# %%
avg.sort_values()
# Out:
# 500     19.1
# 451     19.3
# 1713    19.9
# 171     20.6
# 3704    20.7
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
avg
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
avg.sort_values(inplace=True)

# %%
avg
# Out:
# 500     19.1
# 451     19.3
# 1713    19.9
# 171     20.6
# 3704    20.7
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
average_data = avg.copy

# %%
average_data
# Out:
# <bound method NDFrame.copy of 500     19.1
# 451     19.3
# 1713    19.9
# 171     20.6
# 3704    20.7
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64>

# %%
average_data
# Out:
# <bound method NDFrame.copy of 500     19.1
# 451     19.3
# 1713    19.9
# 171     20.6
# 3704    20.7
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64>

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int32

# %%
dataframe.sort_index()
# Out:
# Youtuber Name
# Aaron Archer        136
# Aaron Bishop        151
# Aaron Brown          51
# Aaron Burns         314
# Aaron Carrillo      210
#                    ...
# Zachary Phillips    478
# Zachary Russell      81
# Zachary Shelton     446
# Zoe Peterson         78
# Zoe Smith            83
# Name: Total Videos, Length: 5000, dtype: int32

# %%
youtube = pd.read_csv('youtube_2025_dataset_202504061614.csv')

# %%
youtube
# Out:
#                      Channel Name       Youtuber Name  Total Videos  \
# 0                 Smith-Ross Labs          Eric Patel            68
# 1                Sandoval PLC Hub  Cynthia Harrington           128
# 2     Jones, Moore and Ho Network       Amanda Walker           282
# 3            Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4              Wilson LLC Studios     Matthew Sherman           129
# ...                           ...                 ...           ...
# 4995        Flores-Daniel Studios       Jasmine Smith           106
# 4996     Spencer and Sons Studios      John Rasmussen           130
# 4997       Obrien-Roberts Studios          Lisa Burke           179
# 4998                 King Ltd Hub          Steve Diaz           182
# 4999            Henry Ltd Studios         Austin Tate            92
#
#                               Best Video  Avg Video Length (min)  \
# 0              VR Challenge: Review 2023                    24.8
# ...

# %%
subs = youtube['Total Subscribers']

# %%
subs
# Out:
# 0       8264152
# 1       8768222
# 2       6163386
# 3       4712268
# 4       9592017
#          ...
# 4995    2665835
# 4996     136992
# 4997    2314561
# 4998    6954832
# 4999    6785166
# Name: Total Subscribers, Length: 5000, dtype: int64

# %% [markdown]
# ### Mathematical functions in Pandas
#
# #### 1) sum() --> sum of all values present inside the series
# #### 2) product() --> product of all values in the series
# #### 3) mean() --> provides us with the average value of the data column.
# #### for e.g. --> company data --> salary --> average value for that column --> salary = 6,6,8,9,11,,, mean = (6+6+8+9+11)/5 --> 8 LPA
#
# #### median() --> also provides the idea about the average of the data. for coming up with median, we need to sort the values in ascending manner and then the middle value after sorting the data --> median; data ----> salary --> 70 lakh (outlier), ---> avg --> 7+8+6+9+
#
# #### mode() --> mode() --> provides us with the idea that which value is getting repeated maximum number of times.
#
# #### std() --> if i need to get thet idea that how the values inside the series are distributed from the average or mean value then we can come up with the standard deviation
# #### salary --> 7,8,6,6.5,7.5 --> low standard deviation
# #### salary --> 7,15,4,20,28,17 --> high standard deviation
#
# #### variance --> variance also provides the insight about the distribution of the data from the mean value and variance is the square of the standard deviation.
# #### standard deviation = (|mean - variance 1| + |mean - variance 2| + ...) / total count of values
#
# #### variance = std**2
#
# #### min() --> minimum value in the series
# #### max() --> maximum value in the series
#
#
# ## describe () --> provides the idea about the summary of the important mathematical calculations for the data.
#
# ### below ideas we'll be getting after using describe function
# #### min --> minimum value
# #### max --> maximum value
# #### mean --> average value
# #### std --> standard deviation
# #### 25%ile --> 25% of the values out of my all values are less than this specific value
# #### 50% --> 50% of the values out of my all values are less than this specific value
# #### 75% --> 75% of the values out of my all values are less than this specific value
# #### count ----> total number of rows in the column
#
# #### JEE Mains --> 25% --> my score in JEE Mains was greater than 25% of the total applicants who applied in JEE

# %%
subs.sum()
# Out:
# np.int64(25292407967)

# %%
subs.product()
# Out:
# np.int64(0)

# %%
subs.mean()
# Out:
# np.float64(5058481.5934)

# %%
subs.median()
# Out:
# np.float64(5105967.0)

# %%
subs.mode()
# Out:
# 0          1755
# 1          2910
# 2          8649
# 3          9029
# 4          9436
#          ...
# 4995    9991900
# 4996    9992512
# 4997    9995049
# 4998    9999559
# 4999    9999975
# Name: Total Subscribers, Length: 5000, dtype: int64

# %%
avg.mode()
# Out:
# 0    24.1
# Name: Avg Video Length (min), dtype: float64

# %%
avg
# Out:
# 500     19.1
# 451     19.3
# 1713    19.9
# 171     20.6
# 3704    20.7
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
avg.std()
# Out:
# np.float64(0.8745549483431755)

# %%
avg.var()
# Out:
# np.float64(0.7648463576715343)

# %%
avg.min()
# Out:
# np.float64(19.1)

# %%
avg.max()
# Out:
# np.float64(28.9)

# %%
avg.describe()
# Out:
# count    5000.000000
# mean       24.004540
# std         0.874555
# min        19.100000
# 25%        23.500000
# 50%        24.000000
# 75%        24.500000
# max        28.900000
# Name: Avg Video Length (min), dtype: float64

# %% [markdown]
# ### Indexing in series (to have the access over the certain value or values)
#
# #### 1) Positive indexing (just like list) --> starts from 0 to forward direction
# #### 2) NO Negative indexing
# #### 3) Slicing --> In series we can get the certain values over a given specific range and we can do it using [initial_value, final_value + 1]
#
# #### 4) Fancy indexing --> If i want the specific value from the series then we go with fancy indexing
#
# #### 5) Indexing with labels --> A series which is consisting of labels as the index or custom index, then for this data we can retrieve the info using that custom index or label

# %%
avg
# Out:
# 500     19.1
# 451     19.3
# 1713    19.9
# 171     20.6
# 3704    20.7
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
avg[0]
# Out:
# np.float64(24.8)

# %%
avg[5]
# Out:
# np.float64(24.2)

# %%
## avg[-1] error

# %%
avg
# Out:
# 500     19.1
# 451     19.3
# 1713    19.9
# 171     20.6
# 3704    20.7
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
avg[7:18]
# Out:
# 3954    20.9
# 3627    21.0
# 210     21.1
# 1511    21.2
# 2529    21.3
# 3105    21.3
# 3924    21.3
# 1896    21.3
# 3710    21.3
# 1526    21.4
# 3499    21.4
# Name: Avg Video Length (min), dtype: float64

# %%
### If i want the values skipped as a certain value

avg[2:21:2]
# Out:
# 1713    19.9
# 3704    20.7
# 3456    20.9
# 3627    21.0
# 1511    21.2
# 3105    21.3
# 1896    21.3
# 1526    21.4
# 2705    21.4
# 3347    21.4
# Name: Avg Video Length (min), dtype: float64

# %%
### Reverse values in a Series

avg[::-1]
# Out:
# 361     28.9
# 1467    28.4
# 364     28.3
# 925     28.1
# 2748    28.0
#         ...
# 3704    20.7
# 171     20.6
# 1713    19.9
# 451     19.3
# 500     19.1
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
avg[[2,4,9]]
# Out:
# 2    24.0
# 4    24.6
# 9    24.2
# Name: Avg Video Length (min), dtype: float64

# %%
avg[[55,1008,79,56,65]]
# Out:
# 55      24.9
# 1008    23.3
# 79      25.1
# 56      23.0
# 65      25.8
# Name: Avg Video Length (min), dtype: float64

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int32

# %%
dataframe['Steve Diaz']
# Out:
# np.int32(182)

# %%
dataframe['Jasmine Smith']
# Out:
# Youtuber Name
# Jasmine Smith    244
# Jasmine Smith    418
# Jasmine Smith    106
# Name: Total Videos, dtype: int32

# %% [markdown]
# ## Editing series (Bring the changes into the values stored inside the series)
#
# #### 1) Using Indexing  --> df[0]=65 ----> changing the original value at index 0 to 65

# %%
dataframe['Cynthia Harrington'] = 75

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington     75
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int32

# %%
### I findexing doesn't exist 
dataframe['Amit Kumar Singh'] = 78

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington     75
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Amit Kumar Singh       78
# Name: Total Videos, Length: 5001, dtype: int32

# %%
## Slicing in Series --> df[2:7]=100 --> 100 value will be associated for index 2 to 6

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington     75
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Amit Kumar Singh       78
# Name: Total Videos, Length: 5001, dtype: int32

# %%
avg
# Out:
# 500     19.1
# 451     19.3
# 1713    19.9
# 171     20.6
# 3704    20.7
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
avg[1:5] = 28

# %%
avg
# Out:
# 500     19.1
# 451     28.0
# 1713    28.0
# 171     28.0
# 3704    28.0
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
## Fancy indexing --> df[2,4,8] = [45, 84, 79]

# %%
avg[[4,4998,4996,0]] = [25,21,20,24]

# %%
avg
# Out:
# 500     19.1
# 451     28.0
# 1713    28.0
# 171     28.0
# 3704    28.0
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
## Indexing labelling

dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington     75
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Amit Kumar Singh       78
# Name: Total Videos, Length: 5001, dtype: int32

# %%
dataframe['Eric Patel', 'Jessica Nelson MD', 'Amit Kumar Singh'] = [45,250,100]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Desktop\ABHISHEK\Technical skills\Tutedude\Gen AI\Generative-Artificial-Intelligence\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %% [markdown]
# # Machine Learning Lifecycle
#
# ## Data gathering (storing it into a dataframe)
# ##              ||
# ## Data exploration
# ##              ||
# ## Data cleaning
# ##              ||
# ## Exploratory data analysis (Pandas, Matplotlib, Seaborn)
# ##              ||
# ## Data processing
# ##              ||
# ## Machine learning models

# %% [markdown]
# ### Data Frame --> for reading the content from the tabular data or the data that is stored in a 2-d structure or in rows and column format or consisting of multiple series in combination, we require data frame and on the pandas data frame we can have the functions to explore and to perform manupulations and analysis on the data we are going to store inside it.

# %% [markdown]
# ### Series with Python Functionalities
#
# #### len --> It provides the idea with total number of elements present in the series
#
# #### type --> It provides the idea about the data type in the series
#
# #### dir --> It provides with the idea about all of the methods and attributes associated with the series
#
# #### sorted() --> It sorts the value in ascending manner
#
# #### max --> it calculates the max value in the series
#
# #### min --> it calculates the min value in the series

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington     75
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Amit Kumar Singh       78
# Name: Total Videos, Length: 5001, dtype: int32

# %%
len(dataframe)
# Out:
# 5001

# %%
type(dataframe)
# Out:
# pandas.Series

# %%
dir(dataframe)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
# ...

# %%
avg
# Out:
# 500     19.1
# 451     28.0
# 1713    28.0
# 171     28.0
# 3704    28.0
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
sorted(avg)
# Out:
# [19.1,
#  20.0,
#  20.9,
#  20.9,
#  20.9,
#  21.0,
#  21.0,
#  21.1,
#  21.2,
#  21.3,
#  21.3,
#  21.3,
#  21.3,
#  21.3,
#  21.4,
#  21.4,
#  21.4,
#  21.4,
#  21.4,
#  21.4,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.7,
#  21.7,
#  21.7,
#  21.7,
#  21.7,
#  21.7,
#  21.7,
#  21.7,
#  21.8,
#  21.8,
#  21.8,
#  21.8,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.2,
#  22.2,
#  22.2,
#  22.2,
#  22.2,
#  22.2,
#  22.2,
#  22.2,
#  22.2,
#  22.2,
# ...

# %%
## Package function --> object.function()
## Built in functionalty --> function(object)

# %%
max(avg)
# Out:
# 28.9

# %%
min(avg)
# Out:
# 19.1

# %% [markdown]
# ## Type conversion in series (Just like Python)
#
# #### I can convert the data type of the given series into another data type.
#
# #### Series --> List ---> list(Series)
# #### Series --> Dictionary --> Dict(Series)

# %%
avg
# Out:
# 500     19.1
# 451     28.0
# 1713    28.0
# 171     28.0
# 3704    28.0
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
list_avg = list(avg)

# %%
type(list_avg)
# Out:
# list

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington     75
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Amit Kumar Singh       78
# Name: Total Videos, Length: 5001, dtype: int32

# %%
dict_dataframe = dict(dataframe)

# %%
type(dict_dataframe)
# Out:
# dict

# %% [markdown]
# ### Membership operator
#
# ## Membership operator --> in --> It checks that whether if a value is in the series or not.
# ## It checks for the element in the index or label of the series
# ## We can go with dataframe.values to check that whether if a member is of a series or not.

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington     75
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Amit Kumar Singh       78
# Name: Total Videos, Length: 5001, dtype: int32

# %%
'Amit Singh' in dataframe
# Out:
# False

# %%
'Amit Kumar Singh' in dataframe
# Out:
# True

# %%
90 in dataframe.values
# Out:
# True

# %%
1500 in dataframe.values
# Out:
# False

# %%
150 in dataframe.values
# Out:
# True

# %% [markdown]
# ### Looping in series --> for loop for iterating over the items of the series and for the index iterating we can go with series_name.index

# %%
avg
# Out:
# 500     19.1
# 451     28.0
# 1713    28.0
# 171     28.0
# 3704    28.0
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
for i in avg:
    print(i)
# Out:
# 19.1
# 28.0
# 28.0
# 28.0
# 28.0
# 20.9
# 20.9
# 20.9
# 21.0
# 21.1
# 21.2
# 21.3
# 21.3
# 21.3
# 21.3
# 21.3
# 21.4
# 21.4
# 21.4
# 21.4
# 21.4
# 21.4
# 21.5
# 21.5
# 21.5
# 21.5
# 21.5
# 21.5
# 21.5
# 21.5
# 21.5
# 21.5
# 21.6
# 21.6
# 21.6
# 21.6
# 21.6
# 21.6
# 21.6
# 21.6
# 21.6
# 21.6
# 21.6
# 21.7
# 21.7
# 21.7
# 21.7
# 21.7
# 21.7
# 21.7
# 21.7
# 21.8
# 21.8
# 21.8
# 21.8
# 21.9
# 21.9
# 21.9
# 21.9
# 21.9
# 21.9
# 21.9
# 21.9
# 21.9
# 21.9
# 21.9
# 21.9
# 21.9
# 21.9
# 21.9
# 21.9
# 21.9
# 22.0
# 22.0
# 22.0
# 22.0
# 22.0
# 22.0
# 22.0
# 22.0
# 22.0
# 22.0
# 22.0
# 22.0
# 22.0
# 22.0
# 22.0
# 22.0
# 22.1
# 22.1
# 22.1
# 22.1
# 22.1
# 22.1
# 22.1
# 22.1
# 22.1
# 22.1
# 22.1
# 22.1
# 22.1
# 22.1
# 22.1
# 22.2
# 22.2
# 22.2
# 22.2
# 22.2
# 22.2
# 22.2
# 22.2
# 22.2
# 22.2
# 22.2
# 22.2
# 22.2
# 22.2
# 22.2
# 22.2
# 22.2
# 22.2
# 22.2
# 22.3
# 22.3
# 22.3
# 22.3
# 22.3
# 22.3
# 22.3
# 22.3
# 22.3
# 22.3
# 22.3
# 22.3
# 22.3
# 22.3
# 22.3
# 22.3
# 22.3
# 22.3
# 22.3
# 22.3
# ...

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington     75
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Amit Kumar Singh       78
# Name: Total Videos, Length: 5001, dtype: int32

# %%
for i in dataframe.index:
    print(i)
# Out:
# Eric Patel
# Cynthia Harrington
# Amanda Walker
# Jessica Nelson MD
# Matthew Sherman
# Anna Berry
# Richard Arnold
# Stephanie Potter
# Teresa Aguirre
# Anne Adkins
# David Clark
# Kathleen Weeks
# Melissa Kennedy
# Kimberly Brown
# Jennifer Martinez
# Elizabeth Wright
# Elijah Ruiz
# Thomas Roberts
# Julian Gutierrez
# Sheila Rivera
# Crystal Vargas
# Kevin Marquez
# Gregory Norman
# Jason Hall
# Jacob Patterson
# Daniel Costa
# Vincent Graves
# Anthony Huynh
# Michelle Rogers
# Alison Scott
# Sherry Reed
# Mr. James Montgomery
# Leah Moss
# Shelby Pace
# Tracie Hogan
# Mrs. Katelyn Soto
# Monica Henry
# Kevin Martinez MD
# Kathryn Harris
# Allison Phillips
# Maxwell Anderson
# Terry Meyer
# Wanda Hernandez
# Brenda Boyd
# Anna Frank
# Heather Jefferson
# Michelle Martinez
# Sara Mack
# Christopher Taylor
# Larry Zimmerman
# David Craig
# Antonio Reilly
# Oscar Gallegos
# William White
# Brittany Dickerson
# Jennifer Kane
# Shannon Rodriguez
# Sarah Little
# Timothy Page
# ...

# %%
for i in dataframe.values:
    print(i)
# Out:
# 68
# 75
# 282
# 302
# 129
# 98
# 494
# 133
# 316
# 140
# 52
# 149
# 53
# 299
# 383
# 79
# 373
# 59
# 500
# 332
# 133
# 228
# 445
# 477
# 405
# 423
# 279
# 428
# 269
# 160
# 302
# 484
# 420
# 148
# 460
# 271
# 51
# 208
# 398
# 115
# 343
# 97
# 153
# 406
# 260
# 346
# 133
# 241
# 150
# 56
# 114
# 73
# 246
# 476
# 487
# 327
# 469
# 78
# 468
# 405
# 269
# 124
# 107
# 356
# 412
# 69
# 96
# 205
# 161
# 399
# 255
# 235
# 172
# 416
# 123
# 265
# 377
# 497
# 228
# 388
# 405
# 210
# 463
# 256
# 215
# 163
# 190
# 280
# 492
# 340
# 189
# 101
# 290
# 120
# 53
# 138
# 467
# 145
# 105
# 456
# 258
# 59
# 442
# 136
# 252
# 258
# 402
# 247
# 273
# 198
# 158
# 150
# 116
# 273
# 161
# 391
# 191
# 482
# 308
# 426
# 190
# 124
# 247
# 366
# 345
# 390
# 467
# 140
# 338
# 287
# 91
# 386
# 458
# 330
# 160
# 469
# 424
# 496
# 432
# 356
# 89
# 309
# 152
# 414
# 485
# 304
# 66
# 318
# 99
# 183
# 230
# 308
# 185
# 127
# 414
# 154
# 233
# 191
# 190
# 405
# 57
# 66
# 158
# 328
# 451
# 287
# 346
# 152
# 313
# 276
# ...

# %% [markdown]
# ## Arithmetic operators

# %%
df
# Out:
# 0                   Smith-Ross Labs
# 1                  Sandoval PLC Hub
# 2       Jones, Moore and Ho Network
# 3              Mitchell-Hooper Labs
# 4                Wilson LLC Studios
#                    ...
# 4995          Flores-Daniel Studios
# 4996       Spencer and Sons Studios
# 4997         Obrien-Roberts Studios
# 4998                   King Ltd Hub
# 4999              Henry Ltd Studios
# Name: Channel Name, Length: 5000, dtype: str

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington     75
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Amit Kumar Singh       78
# Name: Total Videos, Length: 5001, dtype: int32

# %%
added_data = dataframe + 100

# %%
added_data
# Out:
# Youtuber Name
# Eric Patel            168
# Cynthia Harrington    175
# Amanda Walker         382
# Jessica Nelson MD     402
# Matthew Sherman       229
#                      ...
# John Rasmussen        230
# Lisa Burke            279
# Steve Diaz            282
# Austin Tate           192
# Amit Kumar Singh      178
# Name: Total Videos, Length: 5001, dtype: int32

# %%
diff_data = added_data - 50

# %%
diff_data
# Out:
# Youtuber Name
# Eric Patel            118
# Cynthia Harrington    125
# Amanda Walker         332
# Jessica Nelson MD     352
# Matthew Sherman       179
#                      ...
# John Rasmussen        180
# Lisa Burke            229
# Steve Diaz            232
# Austin Tate           142
# Amit Kumar Singh      128
# Name: Total Videos, Length: 5001, dtype: int32

# %%
diff_data * 2
# Out:
# Youtuber Name
# Eric Patel            236
# Cynthia Harrington    250
# Amanda Walker         664
# Jessica Nelson MD     704
# Matthew Sherman       358
#                      ...
# John Rasmussen        360
# Lisa Burke            458
# Steve Diaz            464
# Austin Tate           284
# Amit Kumar Singh      256
# Name: Total Videos, Length: 5001, dtype: int32

# %% [markdown]
# ## Relational operators in series

# %%
diff_data > 400
# Out:
# Youtuber Name
# Eric Patel            False
# Cynthia Harrington    False
# Amanda Walker         False
# Jessica Nelson MD     False
# Matthew Sherman       False
#                       ...
# John Rasmussen        False
# Lisa Burke            False
# Steve Diaz            False
# Austin Tate           False
# Amit Kumar Singh      False
# Name: Total Videos, Length: 5001, dtype: bool

# %%
diff_data
# Out:
# Youtuber Name
# Eric Patel            118
# Cynthia Harrington    125
# Amanda Walker         332
# Jessica Nelson MD     352
# Matthew Sherman       179
#                      ...
# John Rasmussen        180
# Lisa Burke            229
# Steve Diaz            232
# Austin Tate           142
# Amit Kumar Singh      128
# Name: Total Videos, Length: 5001, dtype: int32

# %%
400 > diff_data
# Out:
# Youtuber Name
# Eric Patel            True
# Cynthia Harrington    True
# Amanda Walker         True
# Jessica Nelson MD     True
# Matthew Sherman       True
#                       ...
# John Rasmussen        True
# Lisa Burke            True
# Steve Diaz            True
# Austin Tate           True
# Amit Kumar Singh      True
# Name: Total Videos, Length: 5001, dtype: bool

# %%
200 > diff_data
# Out:
# Youtuber Name
# Eric Patel             True
# Cynthia Harrington     True
# Amanda Walker         False
# Jessica Nelson MD     False
# Matthew Sherman        True
#                       ...
# John Rasmussen         True
# Lisa Burke            False
# Steve Diaz            False
# Austin Tate            True
# Amit Kumar Singh       True
# Name: Total Videos, Length: 5001, dtype: bool

# %% [markdown]
# ## Boolean indexing
#
# #### In order to perform the important analysis on the column value, where in a specific index value IF it is meeting a condition that we get true over their else we get false when the condition is not meeting for that specific index.
#
# ##### Boolean index --> True --> condition is true
# ##### Boolean index --> False --> condition is not true

# %%
avg
# Out:
# 500     19.1
# 451     28.0
# 1713    28.0
# 171     28.0
# 3704    28.0
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
### Which youtubers are having average video length greater than 24 minutes

avg > 24
# Out:
# 500     False
# 451      True
# 1713     True
# 171      True
# 3704     True
#         ...
# 2748     True
# 925      True
# 364      True
# 1467     True
# 361      True
# Name: Avg Video Length (min), Length: 5000, dtype: bool

# %%
avg[avg>24]
# Out:
# 451     28.0
# 1713    28.0
# 171     28.0
# 3704    28.0
# 4794    24.1
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 2382, dtype: float64

# %%
avg[avg>24].size
# Out:
# 2382

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington     75
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Amit Kumar Singh       78
# Name: Total Videos, Length: 5001, dtype: int32

# %%
dataframe > 120
# Out:
# Youtuber Name
# Eric Patel            False
# Cynthia Harrington    False
# Amanda Walker          True
# Jessica Nelson MD      True
# Matthew Sherman        True
#                       ...
# John Rasmussen         True
# Lisa Burke             True
# Steve Diaz             True
# Austin Tate           False
# Amit Kumar Singh      False
# Name: Total Videos, Length: 5001, dtype: bool

# %%
dataframe[dataframe>120]
# Out:
# Youtuber Name
# Amanda Walker        282
# Jessica Nelson MD    302
# Matthew Sherman      129
# Richard Arnold       494
# Stephanie Potter     133
#                     ...
# Howard Phelps        126
# Sharon Graham        231
# John Rasmussen       130
# Lisa Burke           179
# Steve Diaz           182
# Name: Total Videos, Length: 4174, dtype: int32

# %%
dataframe[dataframe > 150].size
# Out:
# 3839

# %% [markdown]
# # Plotting graphs in pandas
#
# #### For plotting graphs in pandas, we require plot() --> df.plot()
#
# #### kind parameter --> it decides that what kind of graph you want to plot

# %%
avg
# Out:
# 500     19.1
# 451     28.0
# 1713    28.0
# 171     28.0
# 3704    28.0
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
avg.plot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[164], line 1
# ----> 1 avg.plot()
#       2
#
# File ~\Desktop\ABHISHEK\Technical skills\Tutedude\Gen AI\Generative-Artificial-Intelligence\.venv\Lib\site-packages\pandas\plotting\_core.py:1105, in PlotAccessor.__call__(self, *args, **kwargs)
#    1104 def __call__(self, *args, **kwargs):
# -> 1105     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#    1107     x, y, kind, kwargs = self._get_call_args(
#    1108         plot_backend.__name__, self._parent, args, kwargs
#    1109     )
#    1111     kind = self._kind_aliases.get(kind, kind)
#
# File ~\Desktop\ABHISHEK\Technical skills\Tutedude\Gen AI\Generative-Artificial-Intelligence\.venv\Lib\site-packages\pandas\plotting\_core.py:2251, in _get_plot_backend(backend)
#    2248 if backend_str in _backends:
#    2249     return _backends[backend_str]
# ...

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington     75
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Amit Kumar Singh       78
# Name: Total Videos, Length: 5001, dtype: int32

# %%
dataframe.sort_values(ascending=False)
# Out:
# Youtuber Name
# Julian Gutierrez     500
# Dominique Martin     500
# Jeremiah Freeman     500
# William Jones        500
# Paul Silva           500
#                     ...
# Michael Sims          50
# Brittany Gross        50
# Jay Johnson           50
# Ronald Williams       50
# Christy Hernandez     50
# Name: Total Videos, Length: 5001, dtype: int32

# %%
dataframe.sort_values(ascending=False).head(15)
# Out:
# Youtuber Name
# Julian Gutierrez    500
# Dominique Martin    500
# Jeremiah Freeman    500
# William Jones       500
# Paul Silva          500
# Eric Riley          500
# Philip Adkins       500
# Miguel Ross         500
# David Santiago      500
# Amy Russo           500
# Brian Thompson      499
# James Hall          499
# Kyle Martin         499
# Sara Short          499
# Tina Atkinson       499
# Name: Total Videos, dtype: int32

# %%
dataframe.sort_values(ascending=False).head(15).plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[168], line 1
# ----> 1 dataframe.sort_values(ascending=False).head(15).plot(kind='bar')
#
# File ~\Desktop\ABHISHEK\Technical skills\Tutedude\Gen AI\Generative-Artificial-Intelligence\.venv\Lib\site-packages\pandas\plotting\_core.py:1105, in PlotAccessor.__call__(self, *args, **kwargs)
#    1104 def __call__(self, *args, **kwargs):
# -> 1105     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#    1107     x, y, kind, kwargs = self._get_call_args(
#    1108         plot_backend.__name__, self._parent, args, kwargs
#    1109     )
#    1111     kind = self._kind_aliases.get(kind, kind)
#
# File ~\Desktop\ABHISHEK\Technical skills\Tutedude\Gen AI\Generative-Artificial-Intelligence\.venv\Lib\site-packages\pandas\plotting\_core.py:2251, in _get_plot_backend(backend)
#    2248 if backend_str in _backends:
# ...

# %%
dataframe.sort_values(ascending=False).sample(15)
# Out:
# Youtuber Name
# Jonathan White    218
# Luis Rivera       216
# Rachel Sparks     119
# Paul Craig DDS    480
# Andrea Ramsey     203
# Wendy Mathews     467
# Sara Graham       332
# Craig Young       360
# Michael Murray    257
# Jasmine Howard    233
# Derrick Harper    232
# James Rose        448
# Thomas Johnson    331
# Kayla Fischer     246
# Michael Lewis     257
# Name: Total Videos, dtype: int32

# %%
dataframe.sort_values(ascending=False).sample(15).plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[170], line 1
# ----> 1 dataframe.sort_values(ascending=False).sample(15).plot(kind='bar')
#
# File ~\Desktop\ABHISHEK\Technical skills\Tutedude\Gen AI\Generative-Artificial-Intelligence\.venv\Lib\site-packages\pandas\plotting\_core.py:1105, in PlotAccessor.__call__(self, *args, **kwargs)
#    1104 def __call__(self, *args, **kwargs):
# -> 1105     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#    1107     x, y, kind, kwargs = self._get_call_args(
#    1108         plot_backend.__name__, self._parent, args, kwargs
#    1109     )
#    1111     kind = self._kind_aliases.get(kind, kind)
#
# File ~\Desktop\ABHISHEK\Technical skills\Tutedude\Gen AI\Generative-Artificial-Intelligence\.venv\Lib\site-packages\pandas\plotting\_core.py:2251, in _get_plot_backend(backend)
#    2248 if backend_str in _backends:
# ...

# %%
dataframe.sort_values(ascending=False).sample(15).plot(kind='pie')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[171], line 1
# ----> 1 dataframe.sort_values(ascending=False).sample(15).plot(kind='pie')
#
# File ~\Desktop\ABHISHEK\Technical skills\Tutedude\Gen AI\Generative-Artificial-Intelligence\.venv\Lib\site-packages\pandas\plotting\_core.py:1105, in PlotAccessor.__call__(self, *args, **kwargs)
#    1104 def __call__(self, *args, **kwargs):
# -> 1105     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#    1107     x, y, kind, kwargs = self._get_call_args(
#    1108         plot_backend.__name__, self._parent, args, kwargs
#    1109     )
#    1111     kind = self._kind_aliases.get(kind, kind)
#
# File ~\Desktop\ABHISHEK\Technical skills\Tutedude\Gen AI\Generative-Artificial-Intelligence\.venv\Lib\site-packages\pandas\plotting\_core.py:2251, in _get_plot_backend(backend)
#    2248 if backend_str in _backends:
# ...
